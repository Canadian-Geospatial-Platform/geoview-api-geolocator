# %%
# !rm -rf $HOME/.local/share/Trash/files

# %%
# !conda install -y -c conda-forge gdal
# Out:
# Channels:
#  - conda-forge
#  - nvidia
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.0
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.

# %%
import os
import json
from osgeo import ogr

# %%
import os
import json
from osgeo import ogr

os.environ["OGR_GEOJSON_MAX_OBJ_SIZE"] = "0"  # No limit

# Input and output files
input_file = "fsa_with_bbox.geojson"
output_file = "opensearch_bulk.json"

# Open input GeoJSON
driver = ogr.GetDriverByName("GeoJSON")
data_source = driver.Open(input_file, 0)  # 0 = read-only
layer = data_source.GetLayer()

bulk_docs = []

def round_coords(geom_json, precision=8):
    def round_list(coords):
        if isinstance(coords[0], list):
            return [round_list(c) for c in coords]
        else:
            return [round(c, precision) for c in coords]
    geom_json["coordinates"] = round_list(geom_json["coordinates"])
    return geom_json

def should_simplify(geom_json, size_limit_bytes=9800000):
    size = len(json.dumps(geom_json).encode("utf-8"))
    return size > size_limit_bytes

for feature in layer:
    geom = feature.GetGeometryRef()
    properties = feature.items()

    if geom is None:
        continue

    # Extract bounding box as envelope type for OpenSearch
    envelope = geom.GetEnvelope()
    bbox_envelope = {
        "type": "envelope",
        "coordinates": [
            [envelope[0], envelope[3]],  # top-left: minX, maxY
            [envelope[1], envelope[2]]   # bottom-right: maxX, minY
        ]
    }

    if geom.GetGeometryType() == ogr.wkbMultiPolygon:
        for i in range(geom.GetGeometryCount()):
            polygon = geom.GetGeometryRef(i)
            geom_json = json.loads(polygon.ExportToJson())

            if should_simplify(geom_json):
                print(f"Simplifying oversized geometry for CFSAUID {properties.get('CFSAUID')}")
                simplified_geom = polygon.Simplify(0.0002)
                geom_json = json.loads(simplified_geom.ExportToJson())

            doc = {
                "name": properties.get("CFSAUID", "Unknown"),
                "attributes": properties,
                "bbox": bbox_envelope,
                "location": geom_json
            }
            bulk_docs.append(doc)

    elif geom.GetGeometryType() == ogr.wkbPolygon:
        geom_json = json.loads(geom.ExportToJson())

        if should_simplify(geom_json):
            print(f"Simplifying oversized geometry for CFSAUID {properties.get('CFSAUID')}")
            simplified_geom = geom.Simplify(0.0002)
            geom_json = json.loads(simplified_geom.ExportToJson())

        doc = {
            "name": properties.get("CFSAUID", "Unknown"),
            "attributes": properties,
            "bbox": bbox_envelope,
            "location": geom_json
        }
        bulk_docs.append(doc)

# Write to OpenSearch bulk format
with open(output_file, "w") as f:
    for doc in bulk_docs:
        f.write(json.dumps({ "index": { "_index": "fsa-postal-code-index" } }) + "\n")
        f.write(json.dumps(doc) + "\n")

print(f"Exported {len(bulk_docs)} documents to {output_file} with envelope bbox format.")
# Out:
# Simplifying oversized geometry for CFSAUID X0A
# Exported 178292 documents to opensearch_bulk.json with envelope bbox format.

# %% [markdown]
# Code below will authenticate with OpenSearch endpoint using the SageMaker IAM role

# %%
# !pip install -q boto3
# !pip install -q requests
# !pip install -q requests-aws4auth
# !pip install -q opensearch-py

# %%
import boto3
import requests
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth
from requests_aws4auth import AWS4Auth
import opensearch

# %%
from opensearch import *
region = "ca-central-1"
aos_host = "search-semantic-search-arieibeskhrn6vn2qd7gf5br7q.ca-central-1.es.amazonaws.com"
os_secret_id = "OpenSearchSecret-geocore-semantic-search-with-opensearch-stage"

#awsauth = get_awsauth_from_secret(region, secret_id=os_secret_id)
#awsauth = ("admin", "Semantic123!")
credentials = boto3.Session().get_credentials()
awsauth = AWS4Auth(credentials.access_key, credentials.secret_key, region, 'es', session_token=credentials.token)
    
aos_client =create_opensearch_connection(aos_host, awsauth)
# Out:
# Connection to OpenSearch established: <OpenSearch([{'host': 'search-semantic-search-arieibeskhrn6vn2qd7gf5br7q.ca-central-1.es.amazonaws.com', 'port': 443}])>

# %%
index_name = "fsa-postal-code-index"
index = {
  "mappings": {
    "properties": {
      "CFSAUID":   { "type": "keyword" }, 
      "DGUID":     { "type": "keyword" },
      "PRUID":     { "type": "keyword" },
      "PRNAME":    { "type": "text" },    
      "LANDAREA":  { "type": "float" },
      "LONG":      { "type": "float" },
      "LAT":       { "type": "float" },
      "bbox":      { "type": "geo_shape" },
      "location":  { "type": "geo_shape" } 
    }
  }
}

# %%
delete_aos_index_if_exists(aos_client, index_to_delete=index_name)
# Out:
# Current indexes: ['minilm-pretrain-knn', 'semantic-search-audit-logs', 'minilm-knn-2', '.ql-datasources', '.kibana_92668751_admin_1', 'minilm-knn-multilingual', 'vcs-audit-logs', '.opendistro-reports-definitions', '.kibana_1', '.opendistro_security', '.opendistro-reports-instances', 'minilm-knn', 'vcs-audit-logs-v2', '.plugins-ml-config', '.opensearch-observability', 'audit-logs-stage', 'opensearch_dashboards_sample_data_logs', 'geolocator-audit-logs', 'opensearch_dashboards_sample_data_flights', '.opendistro-job-scheduler-lock', 'fsa-postal-code-index', 'mpnet-mpf-knn']
# Deleted index: fsa-postal-code-index
# Response: {'acknowledged': True}
# Indexes after deletion attempt: ['minilm-pretrain-knn', 'semantic-search-audit-logs', 'minilm-knn-2', '.ql-datasources', '.kibana_92668751_admin_1', 'minilm-knn-multilingual', 'vcs-audit-logs', '.opendistro-reports-definitions', '.kibana_1', '.opendistro_security', '.opendistro-reports-instances', 'minilm-knn', 'vcs-audit-logs-v2', '.plugins-ml-config', '.opensearch-observability', 'audit-logs-stage', 'opensearch_dashboards_sample_data_logs', 'geolocator-audit-logs', 'opensearch_dashboards_sample_data_flights', '.opendistro-job-scheduler-lock', 'mpnet-mpf-knn']

# %%
aos_client.indices.create(index=index_name,body=index,ignore=400)
# Out:
# {'acknowledged': True,
#  'shards_acknowledged': True,
#  'index': 'fsa-postal-code-index'}

# %%
import os
import requests
import time
from requests.exceptions import RequestException

MAX_BYTES = 10_485_760  # 10 MB limit
bulk_file = "opensearch_bulk.json"

with open(bulk_file, "r", encoding="utf-8") as f:
    lines = f.readlines()

print(f"Total lines: {len(lines)}")

buffer = []
buffer_bytes = 0
doc_count = 0
chunk_number = 1

def send_chunk(buffer, chunk_number, start_doc, end_doc):
    data = ''.join(buffer)
    try:
        resp = requests.post(
            f"https://{aos_host}/_bulk",
            auth=awsauth,
            headers={"Content-Type": "application/x-ndjson"},
            data=data
        )
        if resp.status_code != 200:
            print(f"Chunk {chunk_number} ({start_doc}-{end_doc}): Status {resp.status_code}")
            print("Response:", resp.text)
        else:
            print(f"Chunk {chunk_number} ({start_doc}-{end_doc}): Uploaded")
            response_json = resp.json()
            if response_json.get("errors"):
                print("Some items failed in this chunk.")
                for idx, item in enumerate(response_json["items"]):
                    action = next(iter(item))
                    result = item[action]
                    if result.get("error"):
                        print(f"Doc {start_doc + idx}: {result['error']['type']} - {result['error']['reason']}")
    except RequestException as e:
        print(f"Chunk {chunk_number} ({start_doc}-{end_doc}): Request error: {e}")
    time.sleep(0.2)

i = 0
while i < len(lines):
    index_line = lines[i]
    doc_line = lines[i + 1]
    pair = index_line + doc_line
    pair_size = len(pair.encode("utf-8"))

    if buffer_bytes + pair_size > MAX_BYTES:
        # Send the current buffer
        start_doc = doc_count - len(buffer) // 2 + 1
        end_doc = doc_count
        send_chunk(buffer, chunk_number, start_doc, end_doc)
        buffer = []
        buffer_bytes = 0
        chunk_number += 1

    buffer.append(index_line)
    buffer.append(doc_line)
    buffer_bytes += pair_size
    doc_count += 1
    i += 2

# Send any remaining buffer
if buffer:
    start_doc = doc_count - len(buffer) // 2 + 1
    end_doc = doc_count
    send_chunk(buffer, chunk_number, start_doc, end_doc)
# Out:
# Total lines: 356584
# Chunk 1 (1-5230): Uploaded
# Chunk 2 (5231-9991): Uploaded
# Chunk 3 (9992-15686): Uploaded
# Chunk 4 (15687-18979): Uploaded
# Chunk 5 (18980-20731): Uploaded
# Chunk 6 (20732-22836): Uploaded
# Chunk 7 (22837-24044): Uploaded
# Chunk 8 (24045-29140): Uploaded
# Chunk 9 (29141-32136): Uploaded
# Chunk 10 (32137-33254): Uploaded
# Chunk 11 (33255-33580): Uploaded
# Chunk 12 (33581-34157): Uploaded
# Some items failed in this chunk.
# Doc 33933: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 13 (34158-34941): Uploaded
# Chunk 14 (34942-42549): Uploaded
# Chunk 15 (42550-45507): Uploaded
# Chunk 16 (45508-45703): Uploaded
# Some items failed in this chunk.
# Doc 45642: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 17 (45704-46895): Uploaded
# Chunk 18 (46896-50508): Uploaded
# Some items failed in this chunk.
# Doc 50495: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 19 (50509-50958): Uploaded
# Some items failed in this chunk.
# Doc 50620: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 20 (50959-53105): Uploaded
# Chunk 21 (53106-55608): Uploaded
# Chunk 22 (55609-59964): Uploaded
# Chunk 23 (59965-67503): Uploaded
# Chunk 24 (67504-71049): Uploaded
# Chunk 25 (71050-74579): Uploaded
# Some items failed in this chunk.
# Doc 71050: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Doc 72675: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 26 (74580-77113): Uploaded
# Chunk 27 (77114-78614): Uploaded
# Chunk 28 (78615-81682): Uploaded
# Some items failed in this chunk.
# Doc 79385: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 29 (81683-83331): Uploaded
# Chunk 30 (83332-84529): Uploaded
# Some items failed in this chunk.
# Doc 84118: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Doc 84454: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 31 (84530-84821): Uploaded
# Some items failed in this chunk.
# Doc 84546: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Doc 84620: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Doc 84652: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 32 (84822-87110): Uploaded
# Chunk 33 (87111-90748): Uploaded
# Chunk 34 (90749-92963): Uploaded
# Chunk 35 (92964-96701): Uploaded
# Chunk 36 (96702-101433): Uploaded
# Chunk 37 (101434-105876): Uploaded
# Chunk 38 (105877-106341): Uploaded
# Chunk 39 (106342-107500): Uploaded
# Chunk 40 (107501-109934): Uploaded
# Chunk 41 (109935-111789): Uploaded
# Chunk 42 (111790-114052): Uploaded
# Chunk 43 (114053-119743): Uploaded
# Chunk 44 (119744-125344): Uploaded
# Chunk 45 (125345-130515): Uploaded
# Chunk 46 (130516-135563): Uploaded
# Chunk 47 (135564-140946): Uploaded
# Chunk 48 (140947-144036): Uploaded
# Chunk 49 (144037-145021): Uploaded
# Chunk 50 (145022-146223): Uploaded
# Chunk 51 (146224-147947): Uploaded
# Chunk 52 (147948-156613): Uploaded
# Chunk 53 (156614-163509): Uploaded
# Chunk 54 (163510-166568): Uploaded
# Chunk 55 (166569-167152): Uploaded
# Chunk 56 (167153-171565): Uploaded
# Some items failed in this chunk.
# Doc 167324: mapper_parsing_exception - failed to parse field [location] of type [geo_shape]
# Chunk 57 (171566-175806): Uploaded
# Chunk 58 (175807-177204): Uploaded
# Chunk 59 (177205-178045): Uploaded
# Chunk 60 (178046-178292): Uploaded
